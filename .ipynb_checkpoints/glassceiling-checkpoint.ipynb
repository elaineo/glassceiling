# %%
import requests 
from bs4 import BeautifulSoup
import re

# %%
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import os

chromedriver = "/Users/elaine/Dropbox/vcfriendfinder/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
import json

# %%
# links to all employers
empLinks = []
url="http://www.glassdoor.com/Salaries/san-jose-salary-SRCH_IL.0,8_IM761.htm"
#http://www.glassdoor.com/Salaries/san-francisco-salary-SRCH_IL.0,13_IM759_IP1.htm

for x in range(1,300):
    browser = webdriver.Chrome(chromedriver)
    browser.get(url)
    time.sleep(1)

    ent = browser.find_element_by_tag_name("body")
    employers = ent.find_elements_by_class_name("srchSalaryEmployer")

    for emp in employers:
        emp.find_element_by_class_name('alignLt')
        elink = emp.find_element_by_tag_name('a').get_attribute('href')
        empLinks.append(elink)

    url = browser.find_element_by_xpath("//li[@class='next']/a").get_attribute('href')
    browser.quit();

# %%
chrome_options = Options()
chrome_options.add_extension('/Users/elaine/Dropbox/hook.crx')

browser = webdriver.Chrome(chromedriver, chrome_options=chrome_options)


for link in empLinks[42:500]:
    coData = {}
    
    url = link
    titles = {}
    naptime = 0.1
    done = False
    
    while True:
        browser.get(url)
        time.sleep(naptime)
        try:
            ent = browser.find_element_by_tag_name("body")
            company = ent.find_element_by_class_name("h1").text

            positions = ent.find_elements_by_class_name("salaryRow")
            for p in positions:
                title = p.find_element_by_class_name('i-occ').text
                avgsalary = p.find_element_by_class_name('meanPay').get_attribute('innerHTML')
                min_max = p.find_element_by_class_name('rangeValues')
                minsalary = min_max.find_element_by_class_name('alignLt').get_attribute('innerHTML')
                maxsalary = min_max.find_element_by_class_name('alignRt').get_attribute('innerHTML')
                count = p.find_element_by_class_name('salaryCount').text
                count = ''.join([c for c in count if c.isdigit()])
                t = {'mean': avgsalary, 
                     'max': maxsalary, 
                     'min': minsalary, 'count': int(count)} 
                titles[title] = t
                if int(count) < 2 and len(titles) > 1000:
                    done = True
            naptime = 0.1
        except:
            print url
            naptime = 2
            continue

        if done:
            print company
            coData[company] = titles
            with open('SJ_salaries_count.json', 'a') as f:
                json.dump(coData, f)
            break
        try:    
            url = browser.find_element_by_xpath("//li[@class='next']/a").get_attribute('href')
        except:
            print company
            coData[company] = titles
            with open('SJ_salaries_count.json', 'a') as f:
                json.dump(coData, f)
            break
# Out:
# http://www.glassdoor.com/Salary/Juniper-Networks-Salaries-E7224.htm
# Juniper Networks
# Triune Technologies
# http://www.glassdoor.com/Salary/Nanosemantics-Salaries-E273725.htm
# http://www.glassdoor.com/Salary/Nanosemantics-Salaries-E273725_P2.htm
# Nanosemantics
# http://www.glassdoor.com/Salary/KLA-Tencor-Salaries-E1557.htm
# KLA-Tencor
# http://www.glassdoor.com/Salary/Aricent-Salaries-E28187.htm
# http://www.glassdoor.com/Salary/Aricent-Salaries-E28187_P3.htm
# Aricent
# http://www.glassdoor.com/Salary/AMD-Salaries-E15.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P3.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P4.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P5.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P7.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P8.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P9.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P10.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P11.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P13.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P26.htm
# http://www.glassdoor.com/Salary/AMD-Salaries-E15_P28.htm
# AMD
# AMD
# DGN Technologies
# http://www.glassdoor.com/Salary/Cadence-Design-Systems-Salaries-E1217.htm
# http://www.glassdoor.com/Salary/Cadence-Design-Systems-Salaries-E1217_P3.htm
# Cadence Design Systems
# http://www.glassdoor.com/Salary/Broadcom-Salaries-E6926_
# Howard Hughes Medical Institute
# http://www.glassdoor.com/Salary/UC-San-Francisco-Salaries-E32516_P2.htm
# http://www.glassdoor.com/Salary/UC-San-Francisco-Salaries-E32516_P15.htm
# UC San Francisco
# InfoObjects
# http://www.glassdoor.com/Salary/BlueCap-Software-Salaries-E272727.htm
# BlueCap Software
# http://www.glassdoor.com/Salary/Staytop-Systems-Salaries-E281919.htm
# Staytop Systems
# Infinera
# Uniquify
# http://www.glassdoor.com/Salary/Novellus-Salaries-E1717_P2.htm
# http://www.glassdoor.com/Salary/Novellus-Salaries-E1717_P3.htm
# http://www.glassdoor.com/Salary/Novellus-Salaries-E1717_P7.htm
# Novellus
# http://www.glassdoor.com/Salary/Super-Micro-Computer-Inc-Supermicro-Salaries-E7993_P6.htm
# Super Micro Computer, Inc. (Supermicro)
# http://www.glassdoor.com/Salary/Ariba-Salaries-E7917_P3.htm
# http://www.glassdoor.com/Salary/Ariba-Salaries-E7917_P8.htm
# Ariba
# http://www.glassdoor.com/Salary/Silvaco-Salaries-E11474_P2.htm
# Silvaco
# http://www.glassdoor.com/Salary/Sunera-Technologies-Salaries-E297555.htm
# Sunera Technologies
# http://www.glassdoor.com/Salary/Clear-Thought-Solutions-Salaries-E375908.htm
# Clear Thought Solutions
# http://www.glassdoor.com/Salary/Xoriant-Salaries-E32629.htm
# http://www.glassdoor.com/Salary/Xoriant-Salaries-E32629_P2.htm
# Xoriant
# http://www.glassdoor.com/Salary/Santa-Clara-County-Office-of-Education-Salaries-E104272.htm
# http://www.glassdoor.com/Salary/Santa-Clara-County-Office-of-Education-Salaries-E104272_P2.htm
# Santa Clara County Office of Education
# http://www.glassdoor.com/Salary/Selectica-Salaries-E8827_P2.htm
# Selectica
# CORE Education & Technologies
# http://www.glassdoor.com/Salary/Spirent-Communications-Salaries-E38577.htm
# http://www.glassdoor.com/Salary/Spirent-Communications-Salaries-E38577_P3.htm
# http://www.glassdoor.com/Salary/Spirent-Communications-Salaries-E38577_P4.htm
# Spirent Communications
# http://www.glassdoor.com/Salary/Ooyala-Salaries-E273720_P3.htm
# Ooyala
# Applied Micro Circuits
# http://www.glassdoor.com/Salary/Trimble-Navigation-Salaries-E2067_P2.htm
# http://www.glassdoor.com/Salary/Trimble-Navigation-Salaries-E2067_P5.htm
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-8-de21e228601d> in <module>()
#      14
#      15     while True:
# ---> 16         browser.get(url)
#      17         time.sleep(naptime)
#      18         try:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in get(self, url)
#     205         Loads a web page in the current browser session.
#     206         """
# --> 207         self.execute(Command.GET, {'url': url})
#     208
#     209     @property
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/selenium/webdriver/remote/webdriver.pyc in execute(self, driver_command, params)
#     193         response = self.command_executor.execute(driver_command, params)
#     194         if response:
# --> 195             self.error_handler.check_response(response)
#     196             response['value'] = self._unwrap_value(
#     197                 response.get('value', None))
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/selenium/webdriver/remote/errorhandler.pyc in check_response(self, response)
#     168         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     169             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 170         raise exception_class(message, screen, stacktrace)
#     171
#     172     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 10.000
#   (Session info: chrome=44.0.2403.107)
#   (Driver info: chromedriver=2.9.248307,platform=Mac OS X 10.10.4 x86_64)

# %%
with open('SJ_links.json', 'r') as f:
    empLinks = json.load(f)

# %%
empLinks.index(link)
# Out:
# 229
